# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('D:\Downloads\Weight_and_Height1.csv')

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:, -1].values

# %%
dataset.describe()
# Out:
#        Weight (kg)  Standing Height (cm)
# count   228.000000            228.000000
# mean     84.484649            165.934211
# std      22.788413              9.795003
# min      46.000000            143.900000
# 25%      67.675000            158.400000
# 50%      81.050000            164.650000
# 75%      96.725000            174.100000
# max     191.400000            189.000000

# %%
dataset.head()
# Out:
#    Weight (kg)  Standing Height (cm)
# 0         97.1                 160.2
# 1         98.8                 182.3
# 2         74.3                 184.2
# 3        103.7                 185.3
# 4         83.3                 177.1

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Weight (kg)           228 non-null    float64
#  1   Standing Height (cm)  228 non-null    float64
# dtypes: float64(2)
# memory usage: 3.7 KB

# %%
# visualizing the data
plt.figure(figsize=(20,12))
sns.lineplot(data=dataset,x="Weight (kg)",y="Standing Height (cm)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#creating a linear regression model and fit it using existing data
regressor=LinearRegression()
regressor.fit(x,y)
y_predict=list(regressor.predict(x))
#printing value of intercept and slope
print('intercept:',model.intercept_)
print('slope:',model.coef_)
# Out:
# intercept: 151.2612482593015
# slope: [0.1838184]

# %%
#predictions
y_predict[:5]
# Out:
# [168.15873671613247,
#  168.45850598608794,
#  164.13830180143543,
#  169.32254682301846,
#  165.72531558355269]

# %%
plt.scatter(x,y,color='blue')
plt.plot(x,y_predict,color='red')
plt.xlabel('weight(kg)')
plt.ylabel('Standing Height (cm))')
plt.show()

# %%
#r2_score
r2_score(y,y_predict)
# Out:
# 0.168304376994317
